# %%
name="akshaya"
print(name)
# Out:
# akshaya

# %%
name="akshaya"
email="allakshaya@gmail.com"
print(name),print(email)
# Out:
# akshaya
# allakshaya@gmail.com
# (None, None)

# %%
city="pune"
print(city)
# Out:
# pune

# %%
city="pune"
print(city[2])
print(city[-1])
# Out:
# n
# e

# %%
name="akshaya"
print(name[1:4])
# Out:
# ksh

# %%
name="akshaya"
print(len(name))
# Out:
# 7

# %%
s="Hello"
print(s[3])
# Out:
# l

# %%
print("hello"*3)
# Out:
# hellohellohello

# %%
p="akshaya"
print(p.upper())
# Out:
# AKSHAYA

# %%
P="AKSHAYA"
print(p.lower())
# Out:
# akshaya

# %%
s=" I like Java"
print(s.replace("Java","python"))
# Out:
#  I like python

# %%
s="anything something"
print(s.find("something"))
# Out:
# 9

# %%
name=input("Enter the name :")
print("welcome",name)
# Out:
# Enter the name : chinni
# welcome chinni

# %%
p="python"
print(p[::-1])
# Out:
# nohtyp

# %%
s="AKSHAYA"
print(s[::-1])
# Out:
# AYAHSKA

# %%
name="Chinni"
def greet(): 
    
    print("Hello",name)
greet()
# Out:
# Hello Chinni

# %%
def add(a,b):
    return a+b
print(add(10,20))
# Out:
# 30

# %%
def add(a,b,c=0):
   return a+b+c
print(add(10,20))
print(add(10,20,30))
# Out:
# 30
# 60

# %%
def multiply(a,b,c=0):
  return a*b*c
print(multiply(10,20))
print(multiply(10,20,30))
# Out:
# 0
# 6000

# %%
def add(*numbers):
    print(sum(numbers))
add(10,20)
add(10,20,30)
add(10,20,30,40)
# Out:
# 30
# 60
# 100

# %%
def student(*marks):
    print(sum(marks))
add(80,95,99,85,94)
# Out:
# 453
