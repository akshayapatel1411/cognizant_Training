# %%
name="akshaya"
print(name)
# Out:
# akshaya

# %%
name="Akshaya"
email="akshayapatel@1411"
print(name),print(email)
# Out:
# Akshaya
# akshayapatel@1411
# (None, None)

# %%
city
# Out:
# 'pune'
