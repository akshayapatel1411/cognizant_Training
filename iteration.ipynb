# %%
list=[11,22,33,44]
it=iter(list)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# 11
# 22
# 33
# 44

# %%
list=["akshaya","chinni"]
it=iter(list)
print(next(it))
print(next(it))
# Out:
# akshaya
# chinni

# %%
list=["chinni","ammulu","vinny","chandu","laddu","sai"]
it=iter(list)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it))
# Out:
# chinni
# ammulu
# vinny
# chandu
# laddu
# sai
