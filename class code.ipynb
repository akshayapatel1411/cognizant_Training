# %%
class Car:
    name="Bmw"
    color="blue"   

Car1=Car()
print(Car1.color)
print(Car1.name)
# Out:
# blue
# Bmw

# %%
class student:
    def __init__(self,name,age):
     self.name = name
     self.age = age
    
s1 = student("chinni",20)                                                  
print(s1.name)
# Out:
# chinni
