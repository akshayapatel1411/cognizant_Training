# %%
marks=75
if marks>=35:
    print("pass")
else:
    print("fail")
# Out:
# pass

# %%
num1=5
print(num1,'is of type',type(num1))
# Out:
# 5 is of type <class 'int'>

# %%
class car:
    color="Red"
    brand="age"
    speed=120
    car1=car()
car1=(car1.color)
    print(car1.brand)
