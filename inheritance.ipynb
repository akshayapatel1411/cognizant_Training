# %%
class Parent:
    def func1(self):
        print("This function belongs to parent class.")     

class child(Parent):
    def func2(self):
        print("This function belongs child class.")
object=child()
object.func1()
object.func2()
# Out:
# This function belongs to parent class.
# This function belongs child class.
