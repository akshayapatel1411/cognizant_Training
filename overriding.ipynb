# %%
class Parent:
    def func1(self):
        print("this function belongs to parent class.")     

class child(Parent):
    def func2(self):
        print("this function belongs child class.")
object=child()
object.func1()
# Out:
# this function belongs to parent class.
